# %% [markdown]
# This is tested on:
#
# ![image.png](attachment:image.png)
#
# following the parameters in https://github.com/oobabooga/text-generation-webui/pull/570#issuecomment-1486257060 with a raw-text input (a Sci-Fi novel).

# %%
# !python ../helper/download-model.py chavinlo/alpaca-native
# Out:
# Working directory changed to: /workspace/llm-playground/helper/..
# Skipping: .gitattributes
# Skipping: training_args.bin
# ...
# Running: aria2c -c -x 16 -s 16 -k 1M https://huggingface.co/chavinlo/alpaca-native/resolve/main/README.md -d models/chavinlo_alpaca-native -o README.md
# Running: aria2c -c -x 16 -s 16 -k 1M https://huggingface.co/chavinlo/alpaca-native/resolve/main/added_tokens.json -d models/chavinlo_alpaca-native -o added_tokens.json
# Running: aria2c -c -x 16 -s 16 -k 1M https://huggingface.co/chavinlo/alpaca-native/resolve/main/config.json -d models/chavinlo_alpaca-native -o config.json
# Running: aria2c -c -x 16 -s 16 -k 1M https://huggingface.co/chavinlo/alpaca-native/resolve/main/generation_config.json -d models/chavinlo_alpaca-native -o generation_config.json
# Running: aria2c -c -x 16 -s 16 -k 1M https://huggingface.co/chavinlo/alpaca-native/resolve/main/pytorch_model-00001-of-00003.bin -d models/chavinlo_alpaca-native -o pytorch_model-00001-of-00003.bin
# ...

# %%
# !python server.py --model chavinlo_alpaca-native --model_type llama --load-in-8bit --chat --listen
# Out:
# python: can't open file '/workspace/llm-playground/notebooks/server.py': [Errno 2] No such file or directory

# %%
# %cd /workspace/text-generation-webui/
# Out:
# /workspace/text-generation-webui

# %%
# !python server.py --model chavinlo_alpaca-native --model_type llama --load-in-8bit --chat --listen
# Out:
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda116.so
# Loading chavinlo_alpaca-native...
# Loading checkpoint shards: 100%|██████████████████| 3/3 [01:22<00:00, 27.35s/it]
# Loaded the model in 85.55 seconds.
# Loading the extension "gallery"... Ok.
# Running on local URL:  http://0.0.0.0:7860
#
# To create a public link, set `share=True` in `launch()`.
# Loading raw text file dataset...
# Getting model ready...
# Prepping for training...
# Creating new LoRA model...
# Starting training...
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# {'loss': 3.2345, 'learning_rate': 0.00015000000000000001, 'epoch': 0.06}
# {'loss': 2.8388, 'learning_rate': 0.00030000000000000003, 'epoch': 0.12}
# ...

# %%
# !mv loras/test /workspace/llm_playground/storage/
