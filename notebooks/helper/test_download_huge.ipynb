# %%
# !python3 ../helper/download-dataset.py QingyiSi/Alpaca-CoT
# Out:
# Working directory changed to: /workspaces/llm-playground/helper/..
# ...
#   0%|                                                  | 0/1802 [00:00<?, ?it/s]Downloaded: datasets/QingyiSi_Alpaca-CoT/Chain-of-Thought/formatted_cot_data/aqua_train.json
#
#   0%|                                          | 1/1802 [00:00<08:26,  3.55it/s]
#
#   0%| | 0.00  /15.0M  ?iB/s  , File: Chain-of-Thought/formatted_cot_data/esnli_t
#
#
#   0%| | 0.00  /2.81M  ?iB/s  , File: Chain-of-Thought/formatted_cot_data/ecqa_tr
#
#
#
#   0%| | 0.00  /5.12M  ?iB/s  , File: Chain-of-Thought/formatted_cot_data/qed_tra
#
#
#
#
#   0%| | 0.00  /2.25M  ?iB/s  , File: Chain-of-Thought/formatted_cot_data/sensema
#
#
#
#
#
# 100%|█| 548k  /548k   8.26MiB/s , File: Chain-of-Thought/formatted_cot_data/qasc
#
#
#
#  25%|▎| 711k  /2.81M  6.94MiB/s , File: Chain-of-Thought/formatted_cot_data/ecqa
#  10%| | 453k  /4.45M  4.28MiB/s , File: Chain-of-Thought/formatted_cot_data/gsm8
#
# ...
