# %% [markdown]
# <a href="https://colab.research.google.com/github/utensil/llm-playground/blob/main/notebooks/datasets/load_local_dataset_from_dir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 20.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.6 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 11.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.13.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.15.1 multidict-6.0.4 multiprocess-0.70.14 xxhash-3.2.0 yarl-1.9.2

# %%
# !git clone https://github.com/utensil/llm-playground
# Out:
# Cloning into 'llm-playground'...
# remote: Enumerating objects: 1010, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 1010 (delta 110), reused 0 (delta 0), pack-reused 848
# Receiving objects: 100% (1010/1010), 5.98 MiB | 21.73 MiB/s, done.
# Resolving deltas: 100% (616/616), done.

# %%
# %cd llm-playground
# Out:
# /content/llm-playground

# %%
# !python helper/download-dataset.py winglian/evals
# Out:
# Working directory changed to: /content/llm-playground/helper/..
# https://huggingface.co/api/datasets/winglian/evals/tree/main
# b'[{"type":"directory","oid":"455a74625bb0d3b98b18e3b3f48a3a2fa2740eb4","size":0,"path":"custom"},{"type":"directory","oid":"831547ccd85eb2c166f39fe44de7a28dd0cf5cf4","size":0,"path":"hellaswag"},{"type":"directory","oid":"5941a5a7c4da62beb9ea4ed542aad9b1228dbed4","size":0,"path":"hf"},{"type":"directory","oid":"30060f75278460df5dd72aabc2da596272e7dfa0","size":0,"path":"mmlu"},{"type":"directory","oid":"e137e975f4c847cfe3a09baaafdb91bc0834200b","size":0,"path":"openai"},{"type":"file","oid":"4e8bc8604fef9c578fca4348c0b790242d43bde6","size":2475,"path":".gitattributes"},{"type":"file","oid":"898e6749676e6c8d4af62aa732f1a5deeeae9ccd","size":259,"path":"README.md"}]'
# Gathering: custom
# https://huggingface.co/api/datasets/winglian/evals/tree/main/custom
# b'[{"type":"file","oid":"1017f5ae02a8341673b5dac66b8e819f2931f08e","size":624453,"path":"custom/classify-self-chat.jsonl"},{"type":"file","oid":"acfb41ed3b22a1d017ec09305dacc7d33243c327","size":625783,"path":"custom/classify-self-chat.sharegpt.jsonl"},{"type":"file","oid":"c95b8c1fba8deecfe4ce4fd68dcc0384318f1772","size":7848567,"path":"custom/coding-self-chat.jsonl"},{"type":"file","oid":"8720ba5bf54d5a62f6a5945ba000f45864a76a81","size":7868365,"path":"custom/coding-self-chat.sharegpt.jsonl"},{"type":"file","oid":"d6b82b83b168eeacc65a1bcbf90087151381eaba","size":79852,"path":"custom/context_insensitivity.jsonl"},{"type":"file","oid":"c2a2ed8cf512bde88f7da84fbb40a86092114465","size":7979073,"path":"custom/creative-w-critique.cleaned.jsonl"},{"type":"file","oid":"4fb0e6bdf6ad3743d8a03e96bd41c50d8142ad59","size":5296937,"path":"custom/guanaco-cleaned.en.jsonl"},{"type":"file","oid":"1b28d81e62dc226a16514e499176c9bfc2e688b6","size":1842270,"path":"custom/in_context_qa.jsonl"},{"type":"file","oid":"6d66653f6487fcabde372174fa6de1998e37e195","size":1582714,"path":"custom/jokes_explained_500up.jsonl"},{"type":"file","oid":"28c67166dbcc0d21ed867c6999bf45fe3578faf2","size":22694681,"lfs":{"oid":"7477da5a64eafe449fd7989389ea401d45a5864efc7f75c39a9765cbd1acb379","size":22694681,"pointerSize":133},"path":"custom/logic_inference_oa.jsonl"},{"type":"file","oid":"6b85304b539d8e0ddbaa38ddacb708b7e52eb89f","size":3094572,"path":"custom/long_in_context_qa.jsonl"},{"type":"file","oid":"373f2886cea8197464838791249f5e2834a7d1b7","size":394601,"path":"custom/misconceptions.jsonl"},{"type":"file","oid":"723f8b2a50ffb127c425544a0fac8d7883b450e8","size":171981,"path":"custom/n_task.jsonl"},{"type":"file","oid":"dd669ad212d9ea98d31b416af0c3feae5e5f8e9f","size":1116596,"path":"custom/prose-gpt4.jsonl"},{"type":"file","oid":"75c92971d4cf065c363c4f62d77d90efc33b4702","size":1120643,"path":"custom/prose-gpt4.sharegpt.jsonl"},{"type":"file","oid":"ccb103c376e246e3289b2dfc674717cce2d9d02a","size":1127244,"path":"custom/prose-rewrite-gpt4.jsonl"},{"type":"file","oid":"705a1a7eca67183f79aee84224e73e3384234176","size":1129695,"path":"custom/prose-rewrite-gpt4.sharegpt.jsonl"},{"type":"file","oid":"3463830faa6f720d1b4662edfae1c5a639306cfc","size":68778,"path":"custom/prose.jsonl"}]'
# https://huggingface.co/api/datasets/winglian/evals/tree/main/custom?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSmpkWE4wYjIwdmNISnZjMlV1YW5OdmJtd2lmUT09OjUw
# b'{"error":"Tree Entry not found: custom"}'
# Gathering: hellaswag
# https://huggingface.co/api/datasets/winglian/evals/tree/main/hellaswag
# b'[{"type":"file","oid":"9bd3a28289746d37302482122181df7f8558e99f","size":4198676,"path":"hellaswag/hellaswag-concise.jsonl"},{"type":"file","oid":"399a47913d1f77c55629390e27552169854ac0be","size":90564564,"lfs":{"oid":"4bf203666389ec638475b9fad5ad7809bc8fafe03c3d928ccb5906f0312f47eb","size":90564564,"pointerSize":133},"path":"hellaswag/hellaswag-v2.jsonl"},{"type":"file","oid":"a0942e76f52d5933cdb5026f09ef0fa177975de6","size":73133306,"path":"hellaswag/hellaswag.jsonl"}]'
# https://huggingface.co/api/datasets/winglian/evals/tree/main/hellaswag?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSm9aV3hzWVhOM1lXY3ZhR1ZzYkdGemQyRm5MbXB6YjI1c0luMD06NTA%3D
# b'{"error":"Tree Entry not found: hellaswag"}'
# Gathering: hf
# https://huggingface.co/api/datasets/winglian/evals/tree/main/hf
# b'[{"type":"file","oid":"55c0ba3bbd08831b853aa01ce972866e2777b140","size":2049206,"path":"hf/ARC-Challenge.jsonl"},{"type":"file","oid":"d02449bcd756f7bfad179d08a37021239befc97b","size":3222016,"path":"hf/ARC-Easy.jsonl"},{"type":"file","oid":"de4f357a8a64a0888f3f2626767c565b2a98ff6f","size":7790845,"path":"hf/gsm8k.jsonl"},{"type":"file","oid":"66b17d565c2892231a0b9d219b76d931b776a3f5","size":9051949,"path":"hf/piqa.jsonl"},{"type":"file","oid":"fb5086cc634a113ce27f1f768ed570a63c928cf8","size":3938149,"path":"hf/riddle_sense.jsonl"},{"type":"file","oid":"27c6a1dc6fb1270766da11f39d60b677be93542e","size":5894135,"path":"hf/winogrande.jsonl"}]'
# https://huggingface.co/api/datasets/winglian/evals/tree/main/hf?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSm9aaTkzYVc1dlozSmhibVJsTG1wemIyNXNJbjA9OjUw
# b'{"error":"Tree Entry not found: hf"}'
# Gathering: mmlu
# https://huggingface.co/api/datasets/winglian/evals/tree/main/mmlu
# b'[{"type":"file","oid":"75fd4e37f64f3155fe82573d88fc965b4f9d5749","size":141260,"path":"mmlu/abstract_algebra.jsonl"},{"type":"file","oid":"a4de859fb1f6e673616c527e504c90f481e096b7","size":312961,"path":"mmlu/conceptual_physics.jsonl"},{"type":"file","oid":"ee1a9fe43e779d548458deed6dae5131f19ff072","size":216604,"path":"mmlu/formal_logic.jsonl"},{"type":"file","oid":"3501ecfb6db44c0c3e0d9e1f00259453cc84bb91","size":284766,"path":"mmlu/high_school_physics.jsonl"},{"type":"file","oid":"5206e01eaee0c6b67580d5c11ef1858c74a1ba45","size":263345,"path":"mmlu/logical_fallacies.jsonl"}]'
# https://huggingface.co/api/datasets/winglian/evals/tree/main/mmlu?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSnRiV3gxTDJ4dloybGpZV3hmWm1Gc2JHRmphV1Z6TG1wemIyNXNJbjA9OjUw
# b'{"error":"Tree Entry not found: mmlu"}'
# Gathering: openai
# https://huggingface.co/api/datasets/winglian/evals/tree/main/openai
# b'[{"type":"file","oid":"d08e76a7808048bd640f2e28f9d79a47eb3696bb","size":2233732,"path":"openai/tldr.jsonl"}]'
# https://huggingface.co/api/datasets/winglian/evals/tree/main/openai?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSnZjR1Z1WVdrdmRHeGtjaTVxYzI5dWJDSjk6NTA%3D
# b'{"error":"Tree Entry not found: openai"}'
# https://huggingface.co/api/datasets/winglian/evals/tree/main?cursor=ZXlKbWFXeGxYMjVoYldVaU9pSlNSVUZFVFVVdWJXUWlmUT09OjUw
# b'[]'
# Downloading the dataset to datasets/winglian_evals
#   0% 0/35 [00:00<?, ?it/s]
#   0% 0.00/624k [00:00<?, ?iB/s, File: custom/classify-self-chat.jsonl]
#
#   0% 0.00/79.9k [00:00<?, ?iB/s, File: custom/context_insensitivity.jsonl]
#
#
# 100% 79.9k/79.9k [00:00<00:00, 3.39MiB/s, File: custom/context_insensitivity.jsonl]
#
#
#   0% 0.00/1.84M [00:00<?, ?iB/s, File: custom/in_context_qa.jsonl]
#
#
#
# 100% 624k/624k [00:00<00:00, 7.45MiB/s, File: custom/classify-self-chat.jsonl]
# 100% 626k/626k [00:00<00:00, 6.55MiB/s, File: custom/classify-self-chat.sharegpt.jsonl]
#
#   0% 0.00/7.85M [00:00<?, ?iB/s, File: custom/coding-self-chat.jsonl]
#
#  43% 801k/1.84M [00:00<00:00, 7.98MiB/s, File: custom/in_context_qa.jsonl]
#
#
#
# 100% 1.84M/1.84M [00:00<00:00, 13.9MiB/s, File: custom/in_context_qa.jsonl]
#
#
#   0% 0.00/7.98M [00:00<?, ?iB/s, File: custom/creative-w-critique.cleaned.jsonl]
#   8% 621k/7.85M [00:00<00:01, 6.19MiB/s, File: custom/coding-self-chat.jsonl]
#
#
#   0% 0.00/7.87M [00:00<?, ?iB/s, File: custom/coding-self-chat.sharegpt.jsonl]
#
#
#
# 100% 5.30M/5.30M [00:00<00:00, 24.5MiB/s, File: custom/guanaco-cleaned.en.jsonl]
#
#
#
#
#   0% 0.00/395k [00:00<?, ?iB/s, File: custom/misconceptions.jsonl]
#
#   5% 420k/7.98M [00:00<00:01, 4.19MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#  44% 3.47M/7.85M [00:00<00:00, 19.3MiB/s, File: custom/coding-self-chat.jsonl]
#
#
#
#
#   0% 0.00/3.09M [00:00<?, ?iB/s, File: custom/long_in_context_qa.jsonl]
#
#
# 100% 395k/395k [00:00<00:00, 5.44MiB/s, File: custom/misconceptions.jsonl]
#
#
#
#
#   0% 0.00/172k [00:00<?, ?iB/s, File: custom/n_task.jsonl]
#
#  18% 1.44M/7.98M [00:00<00:00, 7.60MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
#
#
#  20% 608k/3.09M [00:00<00:00, 6.07MiB/s, File: custom/long_in_context_qa.jsonl]
#
#
# 100% 172k/172k [00:00<00:00, 2.84MiB/s, File: custom/n_task.jsonl]
#
#  69% 5.41M/7.85M [00:00<00:00, 14.8MiB/s, File: custom/coding-self-chat.jsonl]
#
#  32% 2.54M/7.98M [00:00<00:00, 9.15MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
#
#
#  60% 1.87M/3.09M [00:00<00:00, 9.88MiB/s, File: custom/long_in_context_qa.jsonl]
#
#
#  37% 2.90M/7.87M [00:00<00:00, 10.3MiB/s, File: custom/coding-self-chat.sharegpt.jsonl]
#
#
#
#   0% 0.00/1.12M [00:00<?, ?iB/s, File: custom/prose-gpt4.jsonl]
#  89% 6.99M/7.85M [00:00<00:00, 14.2MiB/s, File: custom/coding-self-chat.jsonl]
#
#  58% 4.61M/7.98M [00:00<00:00, 13.7MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
#
#
# 100% 3.09M/3.09M [00:00<00:00, 10.8MiB/s, File: custom/long_in_context_qa.jsonl]
#
#
# 100% 3.09M/3.09M [00:00<00:00, 9.71MiB/s, File: custom/long_in_context_qa.jsonl]
#
#
#
#
#
#   0% 0.00/1.12M [00:00<?, ?iB/s, File: custom/prose-gpt4.sharegpt.jsonl]
#
#
#
#  70% 778k/1.12M [00:00<00:00, 6.80MiB/s, File: custom/prose-gpt4.jsonl]
#
#
#
#
#
# 100% 7.85M/7.85M [00:00<00:00, 14.1MiB/s, File: custom/coding-self-chat.jsonl]
# 100% 1.12M/1.12M [00:00<00:00, 7.05MiB/s, File: custom/prose-gpt4.jsonl]
#
#
#  75% 5.99M/7.98M [00:00<00:00, 13.3MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
#  72% 5.68M/7.87M [00:00<00:00, 12.3MiB/s, File: custom/coding-self-chat.sharegpt.jsonl]
#
#
#
#
# 100% 1.12M/1.12M [00:00<00:00, 10.1MiB/s, File: custom/prose-gpt4.sharegpt.jsonl]
#
#
#
#
#
#
#   1% 198k/22.7M [00:00<00:11, 1.97MiB/s, File: custom/logic_inference_oa.jsonl]
#   0% 0.00/1.13M [00:00<?, ?iB/s, File: custom/prose-rewrite-gpt4.jsonl]
#
#  99% 7.90M/7.98M [00:00<00:00, 15.2MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
#
#   0% 0.00/68.8k [00:00<?, ?iB/s, File: custom/prose.jsonl]
#
#
# 100% 7.98M/7.98M [00:00<00:00, 12.8MiB/s, File: custom/creative-w-critique.cleaned.jsonl]
#
#
# 100% 7.87M/7.87M [00:00<00:00, 12.6MiB/s, File: custom/coding-self-chat.sharegpt.jsonl]
# 100% 68.8k/68.8k [00:00<00:00, 2.31MiB/s, File: custom/prose.jsonl]
#
#
#
#
#
#
#   3% 617k/22.7M [00:00<00:06, 3.28MiB/s, File: custom/logic_inference_oa.jsonl]
# 100% 1.13M/1.13M [00:00<00:00, 9.99MiB/s, File: custom/prose-rewrite-gpt4.jsonl]
#
#
# 100% 1.13M/1.13M [00:00<00:00, 10.9MiB/s, File: custom/prose-rewrite-gpt4.sharegpt.jsonl]
#
#   0% 0.00/4.20M [00:00<?, ?iB/s, File: hellaswag/hellaswag-concise.jsonl]
#
#
#
#
#
#   5% 1.19M/22.7M [00:00<00:04, 4.34MiB/s, File: custom/logic_inference_oa.jsonl]
#
#   0% 0.00/2.05M [00:00<?, ?iB/s, File: hf/ARC-Challenge.jsonl]
#
#
#
#
#
#   8% 1.88M/22.7M [00:00<00:03, 5.31MiB/s, File: custom/logic_inference_oa.jsonl]
#  15% 631k/4.20M [00:00<00:00, 6.15MiB/s, File: hellaswag/hellaswag-concise.jsonl]
#
#
#   0% 0.00/1.58M [00:00<?, ?iB/s, File: custom/jokes_explained_500up.jsonl]
#
#
#
#   0% 0.00/3.22M [00:00<?, ?iB/s, File: hf/ARC-Easy.jsonl]
#
#  40% 821k/2.05M [00:00<00:00, 8.17MiB/s, File: hf/ARC-Challenge.jsonl]
#
#
#
#
#
#  12% 2.72M/22.7M [00:00<00:03, 6.42MiB/s, File: custom/logic_inference_oa.jsonl]
#  63% 2.63M/4.20M [00:00<00:00, 14.2MiB/s, File: hellaswag/hellaswag-concise.jsonl]
#
#
#  37% 592k/1.58M [00:00<00:00, 5.90MiB/s, File: custom/jokes_explained_500up.jsonl]
#
#
#
# 100% 2.05M/2.05M [00:00<00:00, 10.5MiB/s, File: hf/ARC-Challenge.jsonl]
#
#
#   0% 0.00/7.79M [00:00<?, ?iB/s, File: hf/gsm8k.jsonl]
#
#
#
#
#
# 100% 1.58M/1.58M [00:00<00:00, 8.89MiB/s, File: custom/jokes_explained_500up.jsonl]
#  26% 9/35 [00:01<00:03,  7.47it/s]
#  97% 4.05M/4.20M [00:00<00:00, 12.8MiB/s, File: hellaswag/hellaswag-concise.jsonl]
#
#
#   0% 0.00/90.6M [00:00<?, ?iB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
# 100% 4.20M/4.20M [00:00<00:00, 11.8MiB/s, File: hellaswag/hellaswag-concise.jsonl]
#
#
#   5% 396k/7.79M [00:00<00:01, 3.93MiB/s, File: hf/gsm8k.jsonl]
#
#
#
#
#
#  20% 4.63M/22.7M [00:00<00:02, 7.97MiB/s, File: custom/logic_inference_oa.jsonl]
#
#
#
#  92% 2.95M/3.22M [00:00<00:00, 10.6MiB/s, File: hf/ARC-Easy.jsonl]
#
#
#   0% 296k/90.6M [00:00<00:31, 2.90MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
# 100% 3.22M/3.22M [00:00<00:00, 9.89MiB/s, File: hf/ARC-Easy.jsonl]
#
#
#
#
#
#
#  26% 5.84M/22.7M [00:00<00:01, 9.27MiB/s, File: custom/logic_inference_oa.jsonl]
#   0% 0.00/3.94M [00:00<?, ?iB/s, File: hf/riddle_sense.jsonl]
#
#
#   2% 2.11M/90.6M [00:00<00:07, 11.8MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#  47% 3.63M/7.79M [00:00<00:00, 12.2MiB/s, File: hf/gsm8k.jsonl]
#
#
#
#   0% 0.00/5.89M [00:00<?, ?iB/s, File: hf/winogrande.jsonl]
#
#
#
#
#   0% 0.00/141k [00:00<?, ?iB/s, File: mmlu/abstract_algebra.jsonl]
#
#
#
#
#
#  32% 7.19M/22.7M [00:00<00:01, 10.5MiB/s, File: custom/logic_inference_oa.jsonl]
# 100% 141k/141k [00:00<00:00, 2.62MiB/s, File: mmlu/abstract_algebra.jsonl]
#
#
#
#   4% 3.68M/90.6M [00:00<00:06, 13.4MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#
#   0% 0.00/9.05M [00:00<?, ?iB/s, File: hf/piqa.jsonl]
#
#  62% 4.85M/7.79M [00:00<00:00, 11.9MiB/s, File: hf/gsm8k.jsonl]
#
#
#
#  10% 583k/5.89M [00:00<00:00, 5.76MiB/s, File: hf/winogrande.jsonl]
#
#
#
#
#
#  36% 8.24M/22.7M [00:01<00:01, 10.4MiB/s, File: custom/logic_inference_oa.jsonl]
#  40% 1.56M/3.94M [00:00<00:00, 8.28MiB/s, File: hf/riddle_sense.jsonl]
#
#
#
#
#   4% 384k/9.05M [00:00<00:02, 3.73MiB/s, File: hf/piqa.jsonl]
#
#
#
#
#
#
#   0% 0.00/313k [00:00<?, ?iB/s, File: mmlu/conceptual_physics.jsonl]
#
#
#
#  21% 1.23M/5.89M [00:00<00:00, 6.14MiB/s, File: hf/winogrande.jsonl]
#
#
#   6% 5.03M/90.6M [00:00<00:07, 10.9MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#  78% 6.04M/7.79M [00:00<00:00, 10.3MiB/s, File: hf/gsm8k.jsonl]
#
#
#
#
#
# 100% 313k/313k [00:00<00:00, 4.12MiB/s, File: mmlu/conceptual_physics.jsonl]
#
#
#
#
#
#  16% 1.46M/9.05M [00:00<00:00, 7.66MiB/s, File: hf/piqa.jsonl]
#  61% 2.39M/3.94M [00:00<00:00, 7.36MiB/s, File: hf/riddle_sense.jsonl]
#
#
#
#  35% 2.06M/5.89M [00:00<00:00, 6.90MiB/s, File: hf/winogrande.jsonl]
#
#
#   7% 6.18M/90.6M [00:00<00:08, 9.55MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#
#  26% 2.37M/9.05M [00:00<00:00, 8.25MiB/s, File: hf/piqa.jsonl]
#
#  91% 7.10M/7.79M [00:00<00:00, 9.37MiB/s, File: hf/gsm8k.jsonl]
#  83% 3.29M/3.94M [00:00<00:00, 7.96MiB/s, File: hf/riddle_sense.jsonl]
#
#
#
#  50% 2.98M/5.89M [00:00<00:00, 7.77MiB/s, File: hf/winogrande.jsonl]
#
#
#
#
#
#  45% 10.2M/22.7M [00:01<00:01, 8.40MiB/s, File: custom/logic_inference_oa.jsonl]
#
#
#
#
#
#
# 100% 7.79M/7.79M [00:00<00:00, 9.98MiB/s, File: hf/gsm8k.jsonl]
# 100% 3.94M/3.94M [00:00<00:00, 7.56MiB/s, File: hf/riddle_sense.jsonl]
#
#
#
#
#
# 100% 217k/217k [00:00<00:00, 3.35MiB/s, File: mmlu/formal_logic.jsonl]
#
#
#
#   8% 7.18M/90.6M [00:00<00:09, 8.83MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#  64% 3.75M/5.89M [00:00<00:00, 7.63MiB/s, File: hf/winogrande.jsonl]
#
#
#
#
#
#  49% 11.1M/22.7M [00:01<00:01, 8.36MiB/s, File: custom/logic_inference_oa.jsonl]
#
#
#
#
#  45% 4.04M/9.05M [00:00<00:00, 8.09MiB/s, File: hf/piqa.jsonl]
#
#
#   9% 8.22M/90.6M [00:00<00:08, 9.24MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#  93% 5.49M/5.89M [00:00<00:00, 10.9MiB/s, File: hf/winogrande.jsonl]
#
#
#
#
#
#  54% 12.3M/22.7M [00:01<00:01, 9.20MiB/s, File: custom/logic_inference_oa.jsonl]
#   0% 0.00/285k [00:00<?, ?iB/s, File: mmlu/high_school_physics.jsonl]
#
# 100% 5.89M/5.89M [00:00<00:00, 9.09MiB/s, File: hf/winogrande.jsonl]
#
#
#
#
#
# 100% 263k/263k [00:00<00:00, 4.07MiB/s, File: mmlu/logical_fallacies.jsonl]
# 100% 285k/285k [00:00<00:00, 3.47MiB/s, File: mmlu/high_school_physics.jsonl]
#
#
#
#  10% 9.39M/90.6M [00:00<00:08, 9.92MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#   0% 0.00/2.23M [00:00<?, ?iB/s, File: openai/tldr.jsonl]
#
#
#
#
#
#  59% 13.4M/22.7M [00:01<00:00, 9.68MiB/s, File: custom/logic_inference_oa.jsonl]
#
#
#
#
#  70% 6.30M/9.05M [00:00<00:00, 9.92MiB/s, File: hf/piqa.jsonl]
#
# 100% 2.48k/2.48k [00:00<00:00, 1.34MiB/s, File: .gitattributes]
#
#
#
#  12% 10.8M/90.6M [00:01<00:07, 11.2MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#  33% 739k/2.23M [00:00<00:00, 7.34MiB/s, File: openai/tldr.jsonl]
#
#
#
#
#
#  64% 14.5M/22.7M [00:01<00:00, 10.0MiB/s, File: custom/logic_inference_oa.jsonl]
#
# 100% 259/259 [00:00<00:00, 130kiB/s, File: README.md]
#
#
#
#
#
#  83% 7.52M/9.05M [00:00<00:00, 10.6MiB/s, File: hf/piqa.jsonl]
#
#
#  13% 12.1M/90.6M [00:01<00:06, 11.5MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#  88% 1.97M/2.23M [00:00<00:00, 10.2MiB/s, File: openai/tldr.jsonl]
#
#
#
#
#
# 100% 2.23M/2.23M [00:00<00:00, 10.1MiB/s, File: openai/tldr.jsonl]
# 100% 9.05M/9.05M [00:00<00:00, 9.89MiB/s, File: hf/piqa.jsonl]
#
#
#
#  15% 13.5M/90.6M [00:01<00:06, 12.4MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#
#
#  77% 17.5M/22.7M [00:01<00:00, 13.0MiB/s, File: custom/logic_inference_oa.jsonl]
#
#
#  18% 16.4M/90.6M [00:01<00:04, 17.1MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#
#
#
# 100% 22.7M/22.7M [00:02<00:00, 11.0MiB/s, File: custom/logic_inference_oa.jsonl]
#  29% 10/35 [00:02<00:08,  2.81it/s]
#
#
#  22% 20.2M/90.6M [00:01<00:02, 23.5MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  28% 25.2M/90.6M [00:01<00:02, 31.4MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  34% 30.9M/90.6M [00:01<00:01, 39.0MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  44% 40.0M/90.6M [00:01<00:00, 54.4MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  52% 47.3M/90.6M [00:01<00:00, 60.0MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  62% 56.4M/90.6M [00:01<00:00, 69.1MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#
#
#  73% 65.8M/90.6M [00:02<00:00, 76.8MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#   0% 0.00/73.1M [00:00<?, ?iB/s, File: hellaswag/hellaswag.jsonl]
#
#
#  82% 74.3M/90.6M [00:02<00:00, 79.2MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#   1% 678k/73.1M [00:00<00:10, 6.77MiB/s, File: hellaswag/hellaswag.jsonl]
#   5% 3.44M/73.1M [00:00<00:03, 18.0MiB/s, File: hellaswag/hellaswag.jsonl]
#
#
#  91% 82.3M/90.6M [00:02<00:00, 56.9MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#  10% 7.15M/73.1M [00:00<00:02, 26.5MiB/s, File: hellaswag/hellaswag.jsonl]
#  14% 10.1M/73.1M [00:00<00:02, 27.6MiB/s, File: hellaswag/hellaswag.jsonl]
#  18% 13.0M/73.1M [00:00<00:02, 28.3MiB/s, File: hellaswag/hellaswag.jsonl]
#
#
# 100% 90.6M/90.6M [00:02<00:00, 34.3MiB/s, File: hellaswag/hellaswag-v2.jsonl]
#  57% 20/35 [00:04<00:02,  5.25it/s]
#  22% 16.0M/73.1M [00:00<00:01, 28.9MiB/s, File: hellaswag/hellaswag.jsonl]
#  27% 19.4M/73.1M [00:00<00:01, 30.2MiB/s, File: hellaswag/hellaswag.jsonl]
#  33% 23.9M/73.1M [00:00<00:02, 22.5MiB/s, File: hellaswag/hellaswag.jsonl]
#  39% 28.8M/73.1M [00:01<00:01, 28.4MiB/s, File: hellaswag/hellaswag.jsonl]
#  47% 34.3M/73.1M [00:01<00:01, 34.1MiB/s, File: hellaswag/hellaswag.jsonl]
#  57% 42.0M/73.1M [00:01<00:00, 44.7MiB/s, File: hellaswag/hellaswag.jsonl]
#  70% 51.1M/73.1M [00:01<00:00, 57.2MiB/s, File: hellaswag/hellaswag.jsonl]
#  84% 61.3M/73.1M [00:01<00:00, 69.5MiB/s, File: hellaswag/hellaswag.jsonl]
# 100% 73.1M/73.1M [00:01<00:00, 45.2MiB/s, File: hellaswag/hellaswag.jsonl]
# 100% 35/35 [00:05<00:00,  6.72it/s]

# %%
from datasets import load_dataset, get_dataset_split_names

# %%
get_dataset_split_names("./datasets/winglian_evals/hellaswag")
# Out:
# ['train']

# %%
ds = load_dataset("./datasets/winglian_evals/hellaswag")
# Out:
# Downloading and preparing dataset json/hellaswag to /root/.cache/huggingface/datasets/json/hellaswag-18236f2717ecccc6/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/hellaswag-18236f2717ecccc6/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'choices', 'answer', 'explanation'],
#         num_rows: 84911
#     })
# })

# %%
ds.shape
# Out:
# {'train': (84911, 4)}

# %%
ds.data['train'].to_pandas().head()
# Out:
#                                             question  \
# 0  Then, the man writes over the snow covering th...
# 1  He scrubs in the shampoo and then washes it of...
# 2  A female chef in white uniform shows a stack o...
# 3  He then combs it and blow dries his hair after...
# 4  The man in the blue shirt sits on the chair ne...
#
#                                              choices  answer  \
# 0  [, the man adds wax to the windshield and cuts...       3
# 1  [then rinses it off in the sink., lets his hai...       2
# 2  [contain egg yolks and baking soda., are then ...       3
# 3  [places six screws on the front of the hair th...       1
# 4  [drops the water faucet in the sink., then wal...       3
#
#                                          explanation
# 0  The correct choice is ", the man continues rem...
# 1  The correct choice is "uses an electric clippe...
# 2  The correct choice is "are filled with pastrie...
# 3  The correct choice is "also trims the back and...
# 4  The correct choice is "scrubs in the shampoo a...

# %%
ds_by_dir = load_dataset("./datasets/winglian_evals", data_dir='hellaswag')
# Out:
# WARNING:datasets.builder:Found cached dataset json (/root/.cache/huggingface/datasets/json/winglian_evals-6e111d1b7c4f3a89/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ds_by_dir.shape
# Out:
# {'train': (84911, 4)}

# %%
ds_by_dir.data['train'].to_pandas().head()
# Out:
#                                             question  \
# 0  Then, the man writes over the snow covering th...
# 1  He scrubs in the shampoo and then washes it of...
# 2  A female chef in white uniform shows a stack o...
# 3  He then combs it and blow dries his hair after...
# 4  The man in the blue shirt sits on the chair ne...
#
#                                              choices  answer  \
# 0  [, the man adds wax to the windshield and cuts...       3
# 1  [then rinses it off in the sink., lets his hai...       2
# 2  [contain egg yolks and baking soda., are then ...       3
# 3  [places six screws on the front of the hair th...       1
# 4  [drops the water faucet in the sink., then wal...       3
#
#                                          explanation
# 0  The correct choice is ", the man continues rem...
# 1  The correct choice is "uses an electric clippe...
# 2  The correct choice is "are filled with pastrie...
# 3  The correct choice is "also trims the back and...
# 4  The correct choice is "scrubs in the shampoo a...

# %%
ds_by_file = load_dataset("./datasets/winglian_evals/hellaswag",  data_files=['hellaswag.jsonl', 'hellaswag-v2.jsonl', 'hellaswag-concise.jsonl'])
# Out:
# Downloading and preparing dataset json/hellaswag to /root/.cache/huggingface/datasets/json/hellaswag-ad1562765da2a8e7/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/hellaswag-ad1562765da2a8e7/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ds_by_file.shape
# Out:
# {'train': (84911, 4)}

# %%
ds_by_file.data['train'].to_pandas().head()
# Out:
#                                             question  \
# 0  He also trims the back and sides of his head w...
# 1  The man in the blue shirt sits on the chair ne...
# 2  He uses scissors to trim the hair and give it ...
# 3  He uses an electric clipper to groom the sideb...
# 4  He then combs it and blow dries his hair after...
#
#                                              choices  answer  \
# 0  [poses with how to complete the look using the...       2
# 1  [drops the water faucet in the sink., then wal...       3
# 2  [lifts his look off the camera., comes on the ...       3
# 3  [then picks up some lipstick on the table to a...       1
# 4  [places six screws on the front of the hair th...       1
#
#                                          explanation
# 0  The correct choice is "uses some hair gel to s...
# 1  The correct choice is "scrubs in the shampoo a...
# 2  The correct choice is "then explains how the h...
# 3  The correct choice is "uses scissors to trim t...
# 4  The correct choice is "also trims the back and...
