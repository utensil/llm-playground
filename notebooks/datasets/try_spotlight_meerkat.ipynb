# %% [markdown]
# <a href="https://colab.research.google.com/github/utensil/llm-playground/blob/main/notebooks/datasets/try_spotlight_meerkat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install renumics-spotlight
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting renumics-spotlight
#   Downloading renumics_spotlight-1.0.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.6 MB/s eta 0:00:00
# Collecting aiofiles (from renumics-spotlight)
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.4.4)
# Collecting av (from renumics-spotlight)
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 41.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (8.1.3)
# Collecting databases[aiosqlite] (from renumics-spotlight)
#   Downloading databases-0.7.0-py3-none-any.whl (21 kB)
# Collecting diskcache (from renumics-spotlight)
#   Downloading diskcache-5.6.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 4.3 MB/s eta 0:00:00
# Collecting fastapi>=0.65.2 (from renumics-spotlight)
#   Downloading fastapi-0.96.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: h5py>3.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.8.0)
# Collecting httptools (from renumics-spotlight)
#   Downloading httptools-0.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (414 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.1/414.1 kB 36.7 MB/s eta 0:00:00
# Collecting imagecodecs (from renumics-spotlight)
#   Downloading imagecodecs-2023.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.25.1)
# Collecting importlib_resources<5.8.0 (from renumics-spotlight)
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (7.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.1.2)
# Collecting loguru (from renumics-spotlight)
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (6.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.22.4)
# Collecting orjson (from renumics-spotlight)
#   Downloading orjson-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (23.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.5.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.7.2)
# Collecting pycatch22 (from renumics-spotlight)
#   Downloading pycatch22-0.4.2.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.10.7)
# Collecting pygltflib>=1.15.1 (from renumics-spotlight)
#   Downloading pygltflib-1.15.6.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.27.1)
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.9)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.2.2)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.65.0)
# Collecting trimesh (from renumics-spotlight)
#   Downloading trimesh-3.21.7-py3-none-any.whl (681 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.1/681.1 kB 53.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.5.0)
# Collecting umap-learn (from renumics-spotlight)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting uvicorn (from renumics-spotlight)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Collecting uvloop>=0.17.0 (from renumics-spotlight)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 83.5 MB/s eta 0:00:00
# Collecting validators (from renumics-spotlight)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting wsproto>=0.14 (from renumics-spotlight)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.65.2->renumics-spotlight)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.18.0->renumics-spotlight) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.1.2->renumics-spotlight) (2.1.2)
# Collecting dataclasses-json>=0.0.25 (from pygltflib>=1.15.1->renumics-spotlight)
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting deprecated (from pygltflib>=1.15.1->renumics-spotlight)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->renumics-spotlight)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# Collecting sqlalchemy<1.5,>=1.4.42 (from databases[aiosqlite]->renumics-spotlight)
#   Downloading SQLAlchemy-1.4.48-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.8 MB/s eta 0:00:00
# Collecting aiosqlite (from databases[aiosqlite]->renumics-spotlight)
#   Downloading aiosqlite-0.19.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.0.7)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (6.3.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->renumics-spotlight) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->renumics-spotlight) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->renumics-spotlight) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->renumics-spotlight) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->renumics-spotlight) (3.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->renumics-spotlight) (0.5.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (1.10.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (3.1.0)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn->renumics-spotlight) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn->renumics-spotlight)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators->renumics-spotlight) (4.4.2)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.9 MB/s eta 0:00:00
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->renumics-spotlight)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->renumics-spotlight) (3.3.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn->renumics-spotlight) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->renumics-spotlight) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<1.5,>=1.4.42->databases[aiosqlite]->renumics-spotlight) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.65.2->renumics-spotlight) (3.6.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->renumics-spotlight) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->renumics-spotlight) (21.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pygltflib>=1.15.1->renumics-spotlight) (1.14.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook->renumics-spotlight) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->renumics-spotlight) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->renumics-spotlight) (4.3.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.65.2->renumics-spotlight) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->renumics-spotlight) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->renumics-spotlight) (0.19.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.2.6)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.4.0->dataclasses-json>=0.0.25->pygltflib>=1.15.1->renumics-spotlight)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->renumics-spotlight) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook->renumics-spotlight) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook->renumics-spotlight) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->renumics-spotlight) (2.21)
# Building wheels for collected packages: pygltflib, pycatch22, umap-learn, validators, pynndescent
#   Building wheel for pygltflib (setup.py) ... done
#   Created wheel for pygltflib: filename=pygltflib-1.15.6-py3-none-any.whl size=26316 sha256=0f7c83f64e6921de9c1aa2841e99d3a5dbc87169f6c94b6514003327d2b8f64e
#   Stored in directory: /root/.cache/pip/wheels/bb/41/60/e52cef7b945603a2df661df2ebfc4f79d4c20395809b8e081b
#   Building wheel for pycatch22 (pyproject.toml) ... done
#   Created wheel for pycatch22: filename=pycatch22-0.4.2-cp310-cp310-linux_x86_64.whl size=118866 sha256=4fbc9404e630d08854d75a83073b35a3676d9abd7024c07bf46cf7800a76fe21
#   Stored in directory: /root/.cache/pip/wheels/d1/05/8c/0077a885e7ab81e51339f35e4b91eb1ad86d6b9898cab53dfd
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=0578ed160bf83264de608acffc4622435f3c1430982f8c21a7118f81fe0d3e5a
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=6bcc1390cd1c2af1365b568a9deff4bbde7a701cc85e9b4248bbfe3161636de7
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=c361e4560e594b8fa51dabf45c55e86b191932e5fab6ca354a25d89b1da704e4
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built pygltflib pycatch22 umap-learn validators pynndescent
# Installing collected packages: pycatch22, av, validators, uvloop, trimesh, sqlalchemy, orjson, mypy-extensions, marshmallow, loguru, jedi, importlib_resources, imagecodecs, httptools, h11, diskcache, deprecated, aiosqlite, aiofiles, wsproto, uvicorn, typing-inspect, starlette, marshmallow-enum, databases, pynndescent, fastapi, dataclasses-json, umap-learn, pygltflib, renumics-spotlight
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
#   Attempting uninstall: importlib_resources
#     Found existing installation: importlib-resources 5.12.0
#     Uninstalling importlib-resources-5.12.0:
#       Successfully uninstalled importlib-resources-5.12.0
# Successfully installed aiofiles-23.1.0 aiosqlite-0.19.0 av-10.0.0 databases-0.7.0 dataclasses-json-0.5.7 deprecated-1.2.14 diskcache-5.6.1 fastapi-0.96.0 h11-0.14.0 httptools-0.5.0 imagecodecs-2023.3.16 importlib_resources-5.7.1 jedi-0.18.2 loguru-0.7.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 mypy-extensions-1.0.0 orjson-3.9.0 pycatch22-0.4.2 pygltflib-1.15.6 pynndescent-0.5.10 renumics-spotlight-1.0.0 sqlalchemy-1.4.48 starlette-0.27.0 trimesh-3.21.7 typing-inspect-0.9.0 umap-learn-0.5.3 uvicorn-0.22.0 uvloop-0.17.0 validators-0.20.0 wsproto-1.2.0

# %%
import pandas as pd
from renumics import spotlight

df = pd.read_csv("https://renumics.com/data/mnist/mnist-tiny.csv")
spotlight.show(df, dtype={"image": spotlight.Image, "embedding": spotlight.Embedding})
# Out:
# http://127.0.0.1:35109/

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(35109)"))
# Out:
# https://dlsroimm295-496ff2e9c6d22116-35109-colab.googleusercontent.com/

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(35109)

# %%
# !pip install meerkat-ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting meerkat-ml
#   Downloading meerkat_ml-0.4.11-py2.py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 14.2 MB/s eta 0:00:00
# Collecting dataclasses>=0.6 (from meerkat-ml)
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (1.5.3)
# Collecting dill>=0.3.3 (from meerkat-ml)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (1.22.4)
# Collecting cytoolz (from meerkat-ml)
#   Downloading cytoolz-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.4 MB/s eta 0:00:00
# Collecting ujson (from meerkat-ml)
#   Downloading ujson-5.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (2.0.1+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (1.2.2)
# Requirement already satisfied: tqdm>=4.49.0 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (4.65.0)
# Collecting datasets>=1.4.1 (from meerkat-ml)
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 36.4 MB/s eta 0:00:00
# Collecting pyarrow>=11.0.0 (from meerkat-ml)
#   Downloading pyarrow-12.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (6.0)
# Collecting omegaconf>=2.0.5 (from meerkat-ml)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.2 MB/s eta 0:00:00
# Collecting semver>=2.13.0 (from meerkat-ml)
#   Downloading semver-3.0.0-py3-none-any.whl (17 kB)
# Collecting multiprocess>=0.70.11 (from meerkat-ml)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (0.29.34)
# Collecting progressbar>=2.5 (from meerkat-ml)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fvcore (from meerkat-ml)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (7.7.1)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (7.34.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (0.96.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (0.22.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (13.3.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (40.0.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (1.14.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (3.1.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (5.8.0)
# Collecting sse-starlette (from meerkat-ml)
#   Downloading sse_starlette-1.6.1-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (0.8.10)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from meerkat-ml) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.4.1->meerkat-ml) (2.27.1)
# Collecting xxhash (from datasets>=1.4.1->meerkat-ml)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.4.1->meerkat-ml) (2023.4.0)
# Collecting aiohttp (from datasets>=1.4.1->meerkat-ml)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.8 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets>=1.4.1->meerkat-ml)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=1.4.1->meerkat-ml) (23.1)
# Collecting responses<0.19 (from datasets>=1.4.1->meerkat-ml)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->meerkat-ml) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->meerkat-ml) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->meerkat-ml) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->meerkat-ml) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->meerkat-ml) (3.0.7)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->meerkat-ml) (4.8.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0.5->meerkat-ml)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->meerkat-ml) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->meerkat-ml) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->meerkat-ml) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->meerkat-ml) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->meerkat-ml) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->meerkat-ml) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->meerkat-ml) (16.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->meerkat-ml) (1.15.1)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz->meerkat-ml) (0.12.0)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->meerkat-ml) (1.10.7)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->meerkat-ml) (0.27.0)
# Collecting yacs>=0.1.6 (from fvcore->meerkat-ml)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->meerkat-ml) (2.3.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore->meerkat-ml) (8.4.0)
# Collecting iopath>=0.1.7 (from fvcore->meerkat-ml)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->meerkat-ml) (2.1.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->meerkat-ml) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->meerkat-ml) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat->meerkat-ml) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->meerkat-ml) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->meerkat-ml) (2022.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->meerkat-ml) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->meerkat-ml) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->meerkat-ml) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->meerkat-ml) (3.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer->meerkat-ml) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->meerkat-ml) (0.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->meerkat-ml) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.4.1->meerkat-ml) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.4.1->meerkat-ml) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=1.4.1->meerkat-ml)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets>=1.4.1->meerkat-ml)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=1.4.1->meerkat-ml)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=1.4.1->meerkat-ml)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.6 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=1.4.1->meerkat-ml)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting portalocker (from iopath>=0.1.7->fvcore->meerkat-ml)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->meerkat-ml) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->meerkat-ml) (6.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->meerkat-ml) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->meerkat-ml) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->meerkat-ml) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->meerkat-ml) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->meerkat-ml) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->meerkat-ml) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.4.1->meerkat-ml) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.4.1->meerkat-ml) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=1.4.1->meerkat-ml) (3.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi->meerkat-ml) (3.6.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (6.4.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat->meerkat-ml) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->meerkat-ml) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->meerkat-ml) (1.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->meerkat-ml) (0.5.1)
# Building wheels for collected packages: antlr4-python3-runtime, progressbar, fvcore, iopath
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=25b374e64a280df01f85eaa208c03611a58eaa2f249be118ed33d782fb026762
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12067 sha256=d8c9facda70287858f8a0c39f1bff4afdc134c1a3bc675cb506979c56c6cc7a8
#   Stored in directory: /root/.cache/pip/wheels/cd/17/e5/765d1a3112ff3978f70223502f6047e06c43a24d7c5f8ff95b
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=04443f8518857b7fc5fea06eba98894e30dc27b1b9da36e0e3616499fdd7c61f
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31531 sha256=6ea7d11e17a5719ee58f063ecd620bfa5aaf78423c0f5d1bf72422aeab18e0fc
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built antlr4-python3-runtime progressbar fvcore iopath
# Installing collected packages: progressbar, dataclasses, antlr4-python3-runtime, yacs, xxhash, ujson, semver, pyarrow, portalocker, omegaconf, multidict, frozenlist, dill, cytoolz, async-timeout, yarl, responses, multiprocess, iopath, huggingface-hub, aiosignal, sse-starlette, fvcore, aiohttp, datasets, meerkat-ml
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 12.0.0 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 cytoolz-0.12.1 dataclasses-0.6 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 fvcore-0.1.5.post20221221 huggingface-hub-0.15.1 iopath-0.1.10 meerkat-ml-0.4.11 multidict-6.0.4 multiprocess-0.70.14 omegaconf-2.3.0 portalocker-2.7.0 progressbar-2.5 pyarrow-12.0.0 responses-0.18.0 semver-3.0.0 sse-starlette-1.6.1 ujson-5.7.0 xxhash-3.2.0 yacs-0.1.8 yarl-1.9.2

# %%
# Fix https://github.com/huggingface/datasets/issues/5923#issuecomment-1575788697
# !yes|pip uninstall pyarrow
# !pip install pyarrow==11.0.0
# Out:
# Found existing installation: pyarrow 12.0.0
# Uninstalling pyarrow-12.0.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pyarrow-12.0.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pyarrow/*
# Proceed (Y/n)?   Successfully uninstalled pyarrow-12.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyarrow==11.0.0
#   Downloading pyarrow-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 42.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow==11.0.0) (1.22.4)
# Installing collected packages: pyarrow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# Successfully installed pyarrow-11.0.0

# %%
import os
import meerkat as mk
import numpy as np

# %%
from meerkat.datasets.imagenette import download_imagenette

dataset_dir = "./downloads"
os.makedirs(dataset_dir, exist_ok=True)
download_imagenette(dataset_dir, overwrite=True)
# Out:
# Downloading:   0%|          | 0.00/99.0M [00:00<?, ?B/s]
# Extracting tar archive, this may take a few minutes...

# %%
# !head -n 5 downloads/imagenette2-160/imagenette.csv
# Out:
# label,split,img_path
# cassette player,train,train/n02979186/n02979186_9036.JPEG
# cassette player,train,train/n02979186/n02979186_11957.JPEG
# cassette player,train,train/n02979186/n02979186_9715.JPEG
# cassette player,train,train/n02979186/n02979186_21736.JPEG

# %%
# Create a `DataFrame`
df = mk.from_csv("./downloads/imagenette2-160/imagenette.csv")

# Create an `ImageColumn`` and add it to the `DataFrame`
df["img"] = mk.image(
    df["img_path"], 
    base_dir=os.path.join(dataset_dir, "imagenette2-160")
)
df
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>split</th>
#       <th>img_path</th>
#       <th>img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cassette player</td>
#       <td>train</td>
#       <td>train/n02979186/n02979186_9036.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cassette player</td>
#       <td>train</td>
#       <td>train/n02979186/n02979186_11957.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cassette player</td>
#       <td>train</td>
#       <td>train/n02979186/n02979186_9715.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>cassette player</td>
#       <td>train</td>
#       <td>train/n02979186/n02979186_21736.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>cassette player</td>
#       <td>train</td>
#       <td>train/n02979186/ILSVRC2012_val_00046953.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>13389</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_17521.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>13390</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_20711.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>13391</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_19050.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>13392</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_13831.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>13393</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_1242.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#   </tbody>
# </table>

# %%
img_cell = df["img"][0]
print(f"Indexing the `ImageColumn` returns an object of type: {type(img_cell)}.")
# Out:
# Indexing the `ImageColumn` returns an object of type: <class 'meerkat.columns.deferred.file.FileCell'>.

# %%
img = img_cell()
img
# Out:
# <PIL.Image.Image image mode=RGB size=213x160 at 0x7F26EBB35660>

# %%
imgs = df["img"][1:4]
print(f"Indexing a slice of the `ImageColumn` returns a: {type(imgs)}.")
imgs
# Out:
# Indexing a slice of the `ImageColumn` returns a: <class 'meerkat.columns.deferred.file.FileColumn'>.
# column([FileCell(fn=<...7f26ebb35c90>), FileCell(fn=<...7f26ebb35c90>), FileCell(fn=<...7f26ebb35c90>)], backend=FileColumn

# %%
imgs()
# Out:
# column([<PIL.Image.Im...x7F264AF11EA0>, <PIL.Image.Im...x7F264AF13EB0>, <PIL.Image.Im...x7F264AF13040>], backend=ObjectColumn

# %%
col = mk.column([0,1,2])
col
# Out:
# column([0, 1, 2], backend=PandasScalarColumn

# %%
dcol = col.defer(lambda x: x + 10)
dcol[1]()  # the function is only called at this point!
# Out:
# 11

# %%
valid_df = df[df["split"] == "valid"]
valid_df
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>split</th>
#       <th>img_path</th>
#       <th>img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cassette player</td>
#       <td>valid</td>
#       <td>val/n02979186/n02979186_8971.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cassette player</td>
#       <td>valid</td>
#       <td>val/n02979186/n02979186_14550.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cassette player</td>
#       <td>valid</td>
#       <td>val/n02979186/n02979186_11971.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>cassette player</td>
#       <td>valid</td>
#       <td>val/n02979186/n02979186_11550.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>cassette player</td>
#       <td>valid</td>
#       <td>val/n02979186/n02979186_8751.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>3920</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_17521.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3921</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_20711.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3922</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_19050.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3923</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_13831.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#     <tr>
#       <th>3924</th>
#       <td>gas pump</td>
#       <td>valid</td>
#       <td>val/n03425413/n03425413_1242.JPEG</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#     </tr>
#   </tbody>
# </table>

# %%
blue_col = valid_df.map(
    lambda img: np.array(img)[:, :, 2].mean(), 
    num_workers=2
)

# Add the intensities as a new column in the `DataFrame` 
valid_df["avg_blue"] = blue_col

# %%
import seaborn as sns

plot_df = valid_df[np.isin(valid_df["label"], ["golf ball", "parachute"])]
sns.displot(
    data=plot_df.to_pandas(), 
    x="avg_blue", 
    hue="label", 
    height=3, 
    aspect=2
)
# Out:
# /usr/local/lib/python3.10/dist-packages/meerkat/dataframe.py:901: UserWarning: Could not convert column img of type <class 'meerkat.columns.deferred.file.FileColumn'>, it will be dropped from the output.
#   warnings.warn(

# %%
valid_df["img"][int(np.argmax(valid_df["avg_blue"]))]
# Out:
# FileCell(fn=<meerkat.columns.deferred.file.FileLoader object at 0x7f26ebb35c90>)

# %%
valid_df.write(os.path.join(dataset_dir, "valid_df"))

# %%
valid_df = mk.read(os.path.join(dataset_dir, "valid_df"))

# %%
input_slider = mk.gui.core.Slider(value=2.0)

# %%
page = mk.gui.Page(input_slider, id="quickstart")
page.launch(True)
# Out:
# 'http://localhost:8000/?id=quickstart'

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://hzfwkqtqgg-496ff2e9c6d22116-8000-colab.googleusercontent.com/
